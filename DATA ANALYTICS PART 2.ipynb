# %% [markdown]
# #### Loading libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Loading Dataset

# %%
Location = r'C:\Users\Admin\Untitled Folder 4\loandata.csv'
loan_data = pd.read_csv(Location, index_col = 0, na_values = ['??', '????'])

# %%
loan_data
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002    Male      No          0      Graduate            No
# LP001003    Male     Yes          1      Graduate            No
# LP001005    Male     Yes          0      Graduate           Yes
# LP001006    Male     Yes          0  Not Graduate            No
# LP001008    Male      No          0      Graduate            No
# ...          ...     ...        ...           ...           ...
# LP002978  Female      No          0      Graduate            No
# LP002979    Male     Yes         3+      Graduate            No
# LP002983    Male     Yes          1      Graduate            No
# LP002984    Male     Yes          2      Graduate            No
# LP002990  Female      No          0      Graduate           Yes
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# ...

# %% [markdown]
# #### Explore the dataset

# %%
loan_data.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status  Year_of_the_loan
# Loan_ID
# ...

# %%
loan_data.head(10)
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
# LP001011   Male     Yes          2      Graduate           Yes
# LP001013   Male     Yes          0  Not Graduate            No
# LP001014   Male     Yes         3+      Graduate            No
# LP001018   Male     Yes          2      Graduate            No
# LP001020   Male     Yes          1      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# ...

# %%
loan_data.tail()
# Out:
#           Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# Loan_ID
# LP002978  Female      No          0  Graduate            No             2900
# LP002979    Male     Yes         3+  Graduate            No             4106
# LP002983    Male     Yes          1  Graduate            No             8072
# LP002984    Male     Yes          2  Graduate            No             7583
# LP002990  Female      No          0  Graduate           Yes             4583
#
#           CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# Loan_ID
# LP002978                0.0        71.0             360.0             1.0
# LP002979                0.0        40.0             180.0             1.0
# LP002983              240.0       253.0             360.0             1.0
# LP002984                0.0       187.0             360.0             1.0
# LP002990                0.0       133.0             360.0             0.0
#
# ...

# %%
loan_data.tail(10)
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP002959  Female     Yes          1      Graduate            No
# LP002960    Male     Yes          0  Not Graduate            No
# LP002961    Male     Yes          1      Graduate            No
# LP002964    Male     Yes          2  Not Graduate            No
# LP002974    Male     Yes          0      Graduate            No
# LP002978  Female      No          0      Graduate            No
# LP002979    Male     Yes         3+      Graduate            No
# LP002983    Male     Yes          1      Graduate            No
# LP002984    Male     Yes          2      Graduate            No
# LP002990  Female      No          0      Graduate           Yes
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP002959            12000                0.0       496.0             360.0
# LP002960             2400             3800.0         NaN             180.0
# ...

# %%
loan_data.shape
# Out:
# (614, 13)

# %%
loan_data.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# Year_of_the_loan       int64
# dtype: object

# %%
loan_data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History  Year_of_the_loan
# count      564.000000        614.000000
# mean         0.842199       2010.832248
# std          0.364878         73.207695
# min          0.000000        201.000000
# 25%          1.000000       2012.000000
# 50%          1.000000       2013.000000
# ...

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614 entries, LP001002 to LP002990
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             601 non-null    object
#  1   Married            611 non-null    object
#  2   Dependents         599 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      582 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
#  12  Year_of_the_loan   614 non-null    int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 67.2+ KB

# %%
print(loan_data.describe(include=[object]))
# Out:
#        Gender Married Dependents Education Self_Employed Property_Area  \
# count     601     611        599       614           582           614
# unique      2       2          4         2             2             3
# top      Male     Yes          0  Graduate            No     Semiurban
# freq      489     398        345       480           500           233
#
#        Loan_Status
# count          614
# unique           2
# top              Y
# freq           422

# %%
loan_data.isnull()
# Out:
#           Gender  Married  Dependents  Education  Self_Employed  \
# Loan_ID
# LP001002   False    False       False      False          False
# LP001003   False    False       False      False          False
# LP001005   False    False       False      False          False
# LP001006   False    False       False      False          False
# LP001008   False    False       False      False          False
# ...          ...      ...         ...        ...            ...
# LP002978   False    False       False      False          False
# LP002979   False    False       False      False          False
# LP002983   False    False       False      False          False
# LP002984   False    False       False      False          False
# LP002990   False    False       False      False          False
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002            False              False        True             False
# ...

# %%
loan_data.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# Year_of_the_loan      0
# dtype: int64

# %%
loan_data.isnull().head()
# Out:
#           Gender  Married  Dependents  Education  Self_Employed  \
# Loan_ID
# LP001002   False    False       False      False          False
# LP001003   False    False       False      False          False
# LP001005   False    False       False      False          False
# LP001006   False    False       False      False          False
# LP001008   False    False       False      False          False
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002            False              False        True             False
# LP001003            False              False       False             False
# LP001005            False              False       False             False
# LP001006            False              False       False             False
# LP001008            False              False       False             False
#
#           Credit_History  Property_Area  Loan_Status  Year_of_the_loan
# Loan_ID
# ...

# %%
loan_data.notnull()
# Out:
#           Gender  Married  Dependents  Education  Self_Employed  \
# Loan_ID
# LP001002    True     True        True       True           True
# LP001003    True     True        True       True           True
# LP001005    True     True        True       True           True
# LP001006    True     True        True       True           True
# LP001008    True     True        True       True           True
# ...          ...      ...         ...        ...            ...
# LP002978    True     True        True       True           True
# LP002979    True     True        True       True           True
# LP002983    True     True        True       True           True
# LP002984    True     True        True       True           True
# LP002990    True     True        True       True           True
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             True               True       False              True
# ...

# %%
loan_data.notnull().head()
# Out:
#           Gender  Married  Dependents  Education  Self_Employed  \
# Loan_ID
# LP001002    True     True        True       True           True
# LP001003    True     True        True       True           True
# LP001005    True     True        True       True           True
# LP001006    True     True        True       True           True
# LP001008    True     True        True       True           True
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             True               True       False              True
# LP001003             True               True        True              True
# LP001005             True               True        True              True
# LP001006             True               True        True              True
# LP001008             True               True        True              True
#
#           Credit_History  Property_Area  Loan_Status  Year_of_the_loan
# Loan_ID
# ...

# %%
loan_data.notnull().sum()
# Out:
# Gender               601
# Married              611
# Dependents           599
# Education            614
# Self_Employed        582
# ApplicantIncome      614
# CoapplicantIncome    614
# LoanAmount           592
# Loan_Amount_Term     600
# Credit_History       564
# Property_Area        614
# Loan_Status          614
# Year_of_the_loan     614
# dtype: int64

# %% [markdown]
# #### Visualization of NULL values

# %%
colormap = sns.color_palette("Blues")
sns.heatmap(loan_data.isnull(),cmap = colormap);

# %%
loan_data.corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
# Year_of_the_loan          0.021015          -0.005560    0.045202
#
#                    Loan_Amount_Term  Credit_History  Year_of_the_loan
# ApplicantIncome           -0.045306       -0.014715          0.021015
# CoapplicantIncome         -0.059878       -0.002056         -0.005560
# LoanAmount                 0.039447       -0.008433          0.045202
# Loan_Amount_Term           1.000000        0.001470         -0.012410
# Credit_History             0.001470        1.000000         -0.009595
# Year_of_the_loan          -0.012410       -0.009595          1.000000

# %%
colormap = sns.color_palette("Greens")
sns.heatmap(loan_data.corr(), annot = True, cmap = colormap);

# %%
colormap = sns.color_palette("Reds")
sns.heatmap(loan_data.corr(), annot = True, cmap = colormap)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Dealing with NULL values in the dataset

# %% [markdown]
# ##### Drop with null values

# %%
loan_data.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# Year_of_the_loan      0
# dtype: int64

# %%
loan_data['Married'].dropna(axis = 0, inplace = True)

# %%
loan_data['Married'].isnull().sum()
# Out:
# 3

# %%
loan_data.shape
# Out:
# (614, 13)

# %%
loan_data.dropna(subset = ['Married','Gender'], inplace = True)

# %%
loan_data['Married'].isnull().sum()
# Out:
# 0

# %%
loan_data['Dependents'].fillna(method = 'bfill', inplace = True)

# %%
loan_data['Dependents'].isnull().sum()
# Out:
# 0

# %%
loan_data['Credit_History'].fillna(method = 'pad', inplace = True)

# %%
loan_data['Credit_History'].isnull().sum()
# Out:
# 0

# %%
loan_data['Self_Employed'].fillna(loan_data['Self_Employed'].mode()[0], inplace = True)

# %%
loan_data['Self_Employed'].isnull().sum()
# Out:
# 0

# %%
loan_data['LoanAmount'].fillna(np.mean(loan_data['LoanAmount']), inplace = True)

# %%
loan_data['LoanAmount'].isnull().sum()
# Out:
# 0

# %%
loan_data['Loan_Amount_Term'].fillna(np.mean(loan_data['Loan_Amount_Term']), inplace = True)

# %%
loan_data['Loan_Amount_Term'].isnull().sum()
# Out:
# 0

# %%
plot_area = loan_data['Property_Area'].value_counts()

# %%
plot_area
# Out:
# Semiurban    225
# Urban        198
# Rural        175
# Name: Property_Area, dtype: int64

# %%
c = loan_data['Self_Employed'].value_counts()

# %%
c
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
m = loan_data['Married'].value_counts()
m
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
overall = loan_data['Gender'].value_counts()
overall
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %% [markdown]
# #### Assignment 1

# %% [markdown]
# #### For the given data set, Borrow's behavioural analysis - perform the exploratory analysis, and handle NULL values using various methods, such as dropping, filling etc.
